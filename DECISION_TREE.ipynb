# %% [markdown]
# <a href="https://colab.research.google.com/github/Kowsalyasriganesh/DECISION-TREE/blob/main/DECISION_TREE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from sklearn.metrics import accuracy_score
import graphviz
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
plt.scatter(df.Glucose,df.BloodPressure)
plt.show()

# %%
plt.plot(df.Glucose,df.BloodPressure)
plt.show()

# %%
plt.hist(df.BloodPressure)
plt.show()

# %%
plt.hist(df.Glucose)
plt.show()

# %%
plt.pie(df.Glucose)
plt.show()

# %%
plt.pie(df.Pregnancies)
plt.show()

# %%
plt.stem(df.Glucose,df.BloodPressure)
plt.show()
# Out:
# <ipython-input-23-1e6c01d942b8>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(df.Glucose,df.BloodPressure)

# %%
plt.stem(df.Pregnancies,df.Insulin)
plt.show()
# Out:
# <ipython-input-24-6f1459bd6183>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(df.Pregnancies,df.Insulin)

# %%
plt.polar(df.Pregnancies,df.Insulin)
plt.show()

# %%
plt.polar(df.Glucose,df.BloodPressure)
plt.show()

# %%
plt.bar(df.Glucose,df.BloodPressure)
plt.show()

# %%
plt.boxplot(df.Glucose)
plt.show()

# %%
plt.boxplot(df.Pregnancies)
plt.show()

# %%
plt.boxplot(df.BloodPressure)
plt.show()

# %%
plt.boxplot(df.SkinThickness)
plt.show()

# %%
plt.boxplot(df.Insulin)
plt.show()

# %%
plt.boxplot(df.BMI)
plt.show()

# %%
plt.boxplot(df.DiabetesPedigreeFunction)
plt.show()

# %%
plt.boxplot(df.Age)
plt.show()

# %%
X = df.drop('Outcome', axis = 1)
Y = df['Outcome']

# %%
plt.figure(figsize=(20,15))
plotnumber = 1
for col in X.columns:
  if plotnumber <= 8:
    ax = plt.subplot(5,5,plotnumber)
    sns.boxplot(X[col])
    plotnumber += 1
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **find null values**

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import missingno as msno
msno.bar(df)
plt.show()

# %% [markdown]
# ***ramdom_state = shuffling***
# **# 0- no,1 - yes **
# test and train data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.7, random_state=0)

# %%
a = StandardScaler()
X_train = a.fit_transform(X_train)
X_test = a.transform(X_test)

# %% [markdown]
# **ALGORITHM: DECISION TREE CLASSIFIER**

# %% [markdown]
# **ALGORITHM WILL LEARN**

# %%
clf = DecisionTreeClassifier(criterion = "entropy", random_state = 0)
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
Y_pred = clf.predict(X_test)

# %% [markdown]
# **244-true positives  1-1,**
# **103-false positives 0-1,**
# **86-false negatives  0-0,**
# **105-true negatives  1-0 **

# %% [markdown]
# **ONE OF THE OUTPUT**

# %%
cm = confusion_matrix(Y_test,Y_pred)
cm
# Out:
# array([[244, 103],
#        [ 86, 105]])

# %% [markdown]
# **ACCURACY**

# %% [markdown]
# **OUTPUT**

# %%
import sklearn

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.6486988847583643

# %%
sklearn.metrics.accuracy_score(Y_test, Y_pred)
# Out:
# 0.6486988847583643

# %%
graphviz.Source(export_graphviz (clf,feature_names= X.columns, filled = True))
